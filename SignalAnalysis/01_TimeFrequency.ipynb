# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Follow this [video - time frequency 1](https://youtu.be/3kj8a-U5rZI)

# %%
from scipy.fftpack import fft, fftfreq, fftshift, ifft
from numpy import pi, real

L=20
n=128

x2 = np.linspace(-L/2, L/2, n+1)
x = x2[0:n]

u = np.exp(-x**2)
F_k = np.real(fft(u))

# %%
mpl.rc('figure', figsize=[16,5])

plt.subplot(121)
plt.plot(x, u)

plt.subplot(122)
plt.plot(x, ut)

# %%
plt.subplot(121)
plt.plot(x, np.fft.fftshift(ut))

plt.subplot(122)
plt.plot(x, abs(np.fft.fftshift(ut)))

# %%
plt.plot(fftshift(fftfreq(n)), abs(fftshift(ut)))

# %%
# calculate derivative using fft
F_fd = 2 * pi * (1j) * fftfreq(n, L/n) * F_k
fd = real(ifft(F_fd))

fd2 = -2 * x * u

plt.plot(x, u, 'b', x, fd, 'g', x, fd2, 'r')
